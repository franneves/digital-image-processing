# %% [markdown]
# # <p style="text-align: center;"> Aula Pratica 6
# Nome: Francielly das Neves Lafaete </p>
# Matricula: 2017023382 </p>

# %%
from skimage.transform import rotate
from skimage.feature import local_binary_pattern, greycomatrix, greycoprops
from skimage import data
from skimage.color import label2rgb
from sklearn import cross_validation
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.metrics import accuracy_score 
from random import randint
import matplotlib.pyplot as plt
import numpy as np
from __future__ import print_function
import glob
import skimage.io as io
import random
import random
import numpy as np
from sklearn import cross_validation
from sklearn.datasets import load_iris
from sklearn.datasets import load_digits
from sklearn import grid_search
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import KFold

# %matplotlib inline
# Out:
# C:\Users\franc\Anaconda2\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\franc\Anaconda2\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
'''
    Trains a simple classifier (eg.: SVMs, DT, ...)
'''
def Simple_Classifier_Function(train, target, test, test_target, classifier, clf_name):
    #Start Simple Classifier

    classifier.fit(train, target)

    prediction = classifier.predict(test)
    accuracy = accuracy_score(test_target, prediction)

    print ('%s Accuracy %.2f' % (clf_name, accuracy))
    return accuracy

'''
    Search for the best set of parameters for a determined classifier. In this case, it evaluates only two parameters: C (penalty parameter) and gamma (kernel coefficient).
    These are fundamental for the SVM-RBF classifier.
'''
def Simple_Classifier_Function_Grid_Search(train, target, classifier, C, gamma):
    #Start Classifier Grid Search

    # Parameters to be evaluated
    parameters = {'C': C, 'gamma': gamma}

    # Searching parameters with 6 cores. Verbose prints in screen at each iteration (higher value, more information).
    clf = grid_search.GridSearchCV(classifier, param_grid=parameters, verbose=1, n_jobs=6)

    clf.fit(train, target)
    print (clf.best_score_)
    print (clf.best_params_)

    return clf

# %% [markdown]
# # Carregar imagens de Texturas

# %%
texturas = []
texturas_target = []
pasta= "T21_wallpaper/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("wallpaper")
pasta = "T22_fur/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("fur")
pasta= "T23_knit/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("knit")
pasta= "T24_corduroy/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("corduroy")
pasta = "T25_plaid/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("plaid")

train_text = []
valid_text = []
train_class = []
valid_class = []

#dividir 60% treino, 40%validaçao
from random import randint
for i in range (0,199):
    idx = random.randint(0,199)
    if i <120:
        train_text.append(texturas[idx])
        train_class.append(texturas_target[idx])
    else:
        valid_text.append(texturas[idx])
        valid_class.append(texturas_target[idx])
# Out:
# ['wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid']
# 145
# 54
# 26
# 83
# 177
# 100
# 180
# 51
# 92
# 94
# 154
# 152
# 93
# 147
# 36
# 67
# 90
# 183
# 167
# 13
# 72
# 102
# 107
# 158
# 79
# 198
# 179
# 162
# 181
# 24
# 115
# 69
# 120
# 133
# 62
# 128
# 126
# 115
# 66
# 197
# 114
# 54
# 140
# 181
# 131
# 97
# 96
# 143
# 27
# 47
# 141
# 49
# 22
# 115
# 167
# 37
# 66
# 122
# 35
# 109
# 40
# 70
# 109
# 13
# 101
# 4
# 112
# 49
# 98
# 164
# 188
# 191
# 84
# 82
# 176
# 66
# 124
# 185
# 84
# 160
# 72
# 158
# 37
# 163
# 140
# 160
# 21
# 100
# 131
# 113
# 139
# 157
# 24
# 38
# 56
# 51
# 84
# 100
# 74
# 2
# 128
# 167
# 173
# 11
# 132
# 184
# 3
# 162
# 57
# 161
# 2
# 127
# 101
# 166
# 171
# 105
# 123
# 194
# 142
# 142
# 91
# 131
# 121
# 87
# 8
# 4
# 67
# 122
# 57
# 54
# 65
# 70
# 99
# 177
# 153
# 187
# 8
# 65
# 141
# 8
# 75
# 114
# 136
# 138
# 51
# 44
# 36
# 93
# 140
# 73
# 135
# 13
# 55
# 138
# 94
# 36
# 4
# 72
# 130
# 3
# 11
# 76
# 47
# 190
# 37
# 4
# 72
# 61
# 126
# 147
# 102
# 60
# 178
# 117
# 184
# 179
# 171
# 156
# 108
# 93
# 27
# 166
# 26
# 86
# 70
# 61
# 98
# 148
# 127
# 195
# 6
# 75
# 153
# 20
# 151
# 76
# 111
# 190
# 70

# %% [markdown]
# ### Extraindo caracteristicas com: GLCM

# %%
for i in range (0, len(train_text)):
    train_text[i] = greycomatrix(train_text[i], [5], [0], 256, symmetric=True, normed=True)
for i in range(0, len(valid_text)):
    valid_text[i] = greycomatrix(valid_text[i], [5], [0], 256, symmetric=True, normed=True)
# Out:
# C:\Users\franc\Anaconda2\lib\site-packages\skimage\feature\texture.py:109: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):

# %% [markdown]
# ### Treinando com  Arvore de decisões

# %%
#Treino
train_text = np.array(train_text)
train_class = np.array(train_class)
train_text = np.reshape(train_text, (train_text.shape[0], train_text.shape[1]*train_text.shape[1]))
clf_1 = tree.DecisionTreeClassifier()
clf_1.fit(train_text,train_class)

#validaçao
valid_text = np.array(valid_text)
valid_class = np.array(valid_class)
valid_text = np.reshape(valid_text, (valid_text.shape[0], valid_text.shape[1]*valid_text.shape[2]))
predction = clf_1.predict(valid_text)
accuracy = accuracy_score(valid_class, predction)
print("acuracy: ")
print(accuracy)
# Out:
# acuracy:
# 0.8860759493670886

# %% [markdown]
# ###  Treinando com SVM

# %%
Simple_Classifier_Function(train_text, train_class, valid_text, valid_class, svm.SVC(), 'SVM-RBF') # SVM-RBF, which is the default configuration of the svm.SVC()
Simple_Classifier_Function(train_text, train_class, valid_text, valid_class, svm.LinearSVC(),'Linear SVM') # Linear SVM
# Out:
# SVM-RBF Accuracy 0.16
# Linear SVM Accuracy 0.16
# 0.16455696202531644

# %% [markdown]
# ### Local Binary Pattern

# %%
texturas = []
texturas_target = []
pasta= "T21_wallpaper/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("wallpaper")
pasta = "T22_fur/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("fur")
pasta= "T23_knit/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("knit")
pasta= "T24_corduroy/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("corduroy")
pasta = "T25_plaid/"
for arquivo in glob.glob(pasta + '*.jpg'):
    texturas.append(io.imread(arquivo, as_grey=True))
    texturas_target.append("plaid")


train_text = []
valid_text = []
train_class = []
valid_class = []


#dividir 60% treino, 40%validaçao
from random import randint
for i in range (0,199):
    idx = random.randint(0,199)
    if i <120:
        train_text.append(texturas[idx])
        train_class.append(texturas_target[idx])
    else:
        valid_text.append(texturas[idx])
        valid_class.append(texturas_target[idx])
# Out:
# ['wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'wallpaper', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'fur', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'knit', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'corduroy', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid', 'plaid']
# 192
# 140
# 35
# 158
# 133
# 93
# 41
# 63
# 190
# 64
# 61
# 145
# 82
# 56
# 133
# 102
# 113
# 0
# 155
# 150
# 19
# 148
# 153
# 61
# 156
# 185
# 62
# 134
# 170
# 70
# 36
# 144
# 176
# 15
# 138
# 123
# 188
# 183
# 67
# 117
# 95
# 151
# 21
# 30
# 23
# 25
# 166
# 74
# 50
# 36
# 29
# 74
# 132
# 178
# 28
# 99
# 131
# 75
# 163
# 81
# 150
# 114
# 178
# 81
# 163
# 101
# 38
# 70
# 177
# 112
# 2
# 127
# 88
# 148
# 144
# 139
# 133
# 27
# 76
# 2
# 195
# 148
# 4
# 174
# 176
# 85
# 4
# 186
# 192
# 197
# 161
# 88
# 15
# 117
# 181
# 8
# 24
# 77
# 150
# 155
# 110
# 111
# 15
# 177
# 136
# 144
# 17
# 9
# 179
# 74
# 16
# 68
# 108
# 43
# 184
# 181
# 23
# 91
# 106
# 45
# 99
# 99
# 148
# 68
# 39
# 57
# 36
# 182
# 47
# 190
# 126
# 199
# 48
# 5
# 48
# 43
# 158
# 5
# 96
# 19
# 127
# 12
# 81
# 60
# 75
# 197
# 31
# 171
# 8
# 30
# 190
# 193
# 56
# 183
# 45
# 179
# 27
# 153
# 185
# 7
# 145
# 133
# 189
# 43
# 151
# 65
# 81
# 150
# 103
# 135
# 133
# 167
# 116
# 153
# 105
# 54
# 130
# 193
# 137
# 170
# 10
# 14
# 81
# 174
# 48
# 96
# 164
# 152
# 181
# 117
# 107
# 163
# 196
# 177
# 186
# 143
# 131
# 19
# 53

# %% [markdown]
# ### Extraindo caracteristicas com: Local Binary Pattern

# %%
def hist(lbp):
    n_bins = int(lbp.max() + 1)
    return np.histogram(lbp.ravel(), normed=True, bins=n_bins, range=(0, n_bins))[0]

# %%
# settings for LBP
METHOD = 'uniform'
plt.rcParams['font.size'] = 9
radius = 2
n_points = 8 * radius

for i in range (0, len(train_text)):
    train_text[i] = hist(local_binary_pattern(train_text[i], n_points, radius, METHOD))
for i in range(0, len(valid_text)):
    valid_text[i] = hist(local_binary_pattern(valid_text[i], n_points, radius, METHOD))

# %% [markdown]
# ### Treinando com Arvore de decisoes

# %%
#Treino
clf_1 = tree.DecisionTreeClassifier()
clf_1.fit(train_text,train_class)

#validaçao
valid_text = np.array(valid_text)
valid_class = np.array(valid_class)
valid_text = np.reshape(valid_text, (valid_text.shape[0], valid_text.shape[1]*valid_text.shape[2]))
predction = clf_1.predict(valid_text)
accuracy = accuracy_score(valid_class, predction)
print("acuracy: ")
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-da3d307ac62d> in <module>()
#       2 train_text = np.array(train_text)
#       3 train_class = np.array(train_class)
# ----> 4 train_text = np.reshape(train_text, (train_text.shape[0], train_text.shape[1]*train_text.shape[1]))
#       5 clf_1 = tree.DecisionTreeClassifier()
#       6 clf_1.fit(train_text,train_class)
#
# C:\Users\franc\Anaconda2\lib\site-packages\numpy\core\fromnumeric.pyc in reshape(a, newshape, order)
#     255            [5, 6]])
#     256     """
# --> 257     return _wrapfunc(a, 'reshape', newshape, order=order)
#     258
#     259
#
# C:\Users\franc\Anaconda2\lib\site-packages\numpy\core\fromnumeric.pyc in _wrapfunc(obj, method, *args, **kwds)
#      50 def _wrapfunc(obj, method, *args, **kwds):
#      51     try:
# ---> 52         return getattr(obj, method)(*args, **kwds)
#      53
#      54     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 2160 into shape (120,324)

# %% [markdown]
# ### Treinando com SVM

# %%
Simple_Classifier_Function(train_text, train_class, valid_text, valid_class, svm.SVC(), 'SVM-RBF') # SVM-RBF, which is the default configuration of the svm.SVC()
Simple_Classifier_Function(train_text, train_class, valid_text, valid_class, svm.LinearSVC(),'Linear SVM') # Linear SVM
